# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# load dataset
df = pd.read_excel('Heatmap Dataset.xlsx')

# %%
df.head()
# Out:
#    id       observed_on_string          observed_on  Unnamed: 3  year  \
# 0 NaN  Jun 10, 20179:27 PM EDT  2017-06-07 00:00:00         NaN  2017
# 1 NaN   Jun 4, 20172:28 PM EDT             ########         NaN  2017
# 2 NaN  May 17, 20179:32 AM PDT             ########         NaN  2017
# 3 NaN   May 5, 20179:13 PM PDT  2017-05-04 00:00:00         NaN  2017
# 4 NaN   May 5, 20177:04 PM MDT             ########         NaN  2017
#
#   time_observed_at                   time_zone  user_id user_login  \
# 0     12:52 PM EDT  Eastern Time (US & Canada)      NaN      srall
# 1     12:11 PM EDT  Eastern Time (US & Canada)      NaN      srall
# 2     12:52 PM PDT       Pacific Daylight Time      NaN   leptonia
# 3     12:21 PM PDT       Pacific Daylight Time      NaN   leptonia
# 4              NaN       Central Daylight Time      NaN   bug_eric
#
#         Source  ...  latitude  longitude        species_guess  \
# 0  iNaturalist  ...  40.66750   74.64596  Green Beetle Hanger
# ...

# %%
df['year'].value_counts()
# Out:
# 2021    204
# 2020    171
# 2019     65
# 2022     33
# 2016     26
# 2018     24
# 2017     24
# 2014     24
# 2010     16
# 2015     15
# 2013      9
# 2011      9
# 2009      7
# 2005      7
# 2012      5
# 2003      5
# 2002      4
# 2004      4
# 2008      4
# 2007      2
# 2006      2
# Name: year, dtype: int64
