# %% [markdown]
# # Applying Country Codes to Main Dataset
#
# Using the pycountry package, the country codes will be applied to the Main Dataset for graphing purposes, such as heatmaps.

# %%
import pycountry
import pandas as pd
import numpy as np
import pycountry_convert as pc

# %%
# load dataset
df = pd.read_csv('Main dataset 7-10.csv')

# %%
# looking at data
df.head(10)
# Out:
#           id observed_on_string observed_on         time_observed_at  \
# 0   293700.0          5/21/2013   5/21/2013                      NaN
# 1   803544.0    7/26/2014 10:20   7/26/2014  2014-07-26 17:20:28 UTC
# 2   804805.0      7/4/2014 9:30    7/4/2014  2014-07-04 13:30:02 UTC
# 3   852643.0           7/1/2014    7/1/2014                      NaN
# 4  1050649.0          11/2/2014   11/2/2014                      NaN
# 5  1765681.0          7/11/2015   7/11/2015                      NaN
# 6  1814527.0          7/18/2015   7/18/2015                      NaN
# 7  1876714.0     8/9/2015 20:28    8/9/2015  2015-08-10 00:28:15 UTC
# 8  2010658.0    9/18/2015 21:43   9/18/2015  2015-09-19 01:43:55 UTC
# 9  2648522.0           2/6/2016    2/6/2016                      NaN
#
#                     time_zone  user_id      user_login          user_name  \
# 0  Eastern Time (US & Canada)   4860.0         rcurtis         Rob Curtis
# 1  Pacific Time (US & Canada)   2991.0    sea-kangaroo                NaN
# 2  Eastern Time (US & Canada)   4860.0         rcurtis         Rob Curtis
# 3  Eastern Time (US & Canada)  30601.0      calopteryx  Matthew O'Donnell
# 4                    Auckland  15329.0  stephen_thorpe     Stephen Thorpe
# 5  Eastern Time (US & Canada)  12045.0        larry522     Larry Clarfeld
# 6  Eastern Time (US & Canada)  76331.0        khimmler     Kurtis Himmler
# 7  Eastern Time (US & Canada)   3773.0        anita363              Anita
# 8  Eastern Time (US & Canada)   3773.0        anita363              Anita
# 9                    Auckland  15329.0  stephen_thorpe     Stephen Thorpe
#
#                 created_at               updated_at  ...  \
# 0  2013-06-09 22:09:46 UTC  2022-12-22 17:14:07 UTC  ...
# 1  2014-07-27 05:01:45 UTC  2022-12-17 21:12:01 UTC  ...
# 2  2014-07-28 02:29:17 UTC  2023-01-09 20:58:06 UTC  ...
# 3  2014-08-29 05:02:52 UTC  2023-01-09 20:58:01 UTC  ...
# 4  2014-11-02 02:55:10 UTC  2022-08-24 22:28:06 UTC  ...
# 5  2015-07-15 13:05:04 UTC  2023-01-09 21:12:40 UTC  ...
# 6  2015-07-30 00:06:27 UTC  2023-01-09 20:57:43 UTC  ...
# 7  2015-08-20 17:37:17 UTC  2023-01-09 20:57:37 UTC  ...
# 8  2015-09-29 04:00:23 UTC  2022-12-17 17:45:14 UTC  ...
# 9  2016-02-06 03:26:52 UTC  2022-08-24 22:29:09 UTC  ...
#
#             place_town_name place_county_name place_state_name  \
# 0                       NaN            Summit             Ohio
# 1             Mountain View       Santa Clara       California
# 2                       NaN            Summit             Ohio
# 3                       NaN           Fairfax         Virginia
# 4                       NaN  Auckland Region2         Auckland
# 5                 Woodstock           Windsor          Vermont
# 6        East Brunswick, NJ         Middlesex       New Jersey
# 7  Highland Park New Jersey         Middlesex       New Jersey
# 8  Highland Park New Jersey         Middlesex       New Jersey
# 9                       NaN  Auckland Region2         Auckland
#
#   place_country_name                species_guess  \
# 0      United States       Hesperomyces harmoniae
# 1      United States       Hesperomyces virescens
# 2      United States              Marienkäferpilz
# 3      United States              Marienkäferpilz
# 4        New Zealand  Hesperomyces coccinelloides
# 5      United States       Hesperomyces harmoniae
# 6      United States              Marienkäferpilz
# 7      United States          Green Beetle Hanger
# 8      United States          Green Beetle Hanger
# 9        New Zealand  Hesperomyces coccinelloides
#
#                scientific_name          common_name  iconic_taxon_name  \
# 0       Hesperomyces harmoniae                  NaN              Fungi
# 1       Hesperomyces virescens  Green Beetle Hanger              Fungi
# 2       Hesperomyces virescens  Green Beetle Hanger              Fungi
# 3       Hesperomyces virescens  Green Beetle Hanger              Fungi
# 4  Hesperomyces coccinelloides                  NaN              Fungi
# 5       Hesperomyces harmoniae                  NaN              Fungi
# 6       Hesperomyces virescens  Green Beetle Hanger              Fungi
# 7       Hesperomyces virescens  Green Beetle Hanger              Fungi
# 8       Hesperomyces virescens  Green Beetle Hanger              Fungi
# 9  Hesperomyces coccinelloides                  NaN              Fungi
#
#     taxon_id       Source
# 0  1433448.0  iNaturalist
# 1  1267749.0  iNaturalist
# 2  1267749.0  iNaturalist
# 3  1267749.0  iNaturalist
# 4   707811.0  iNaturalist
# 5  1433448.0  iNaturalist
# 6  1267749.0  iNaturalist
# 7  1267749.0  iNaturalist
# 8  1267749.0  iNaturalist
# 9   707811.0  iNaturalist
#
# [10 rows x 45 columns]

# %%
df_source_not_inaturalist = df.loc[df['Source'] != 'iNaturalist']

# %%
# testing out pycountry package
france = pycountry.countries.get(alpha_2='FR')
france
# Out:
# Country(alpha_2='FR', alpha_3='FRA', flag='🇫🇷', name='France', numeric='250', official_name='French Republic')

# %%
from geopy.geocoders import Nominatim
import pandas as pd

def get_country_code(latlong_series):
    """
    Given a Pandas Series of latitude-longitude coordinates, returns a list of 
    corresponding country codes obtained through reverse geocoding using the 
    Nominatim geocoding service from the geopy library. If a location cannot be 
    found for a given coordinate, the string 'needs to be checked' is returned 
    instead of a country code.

    Parameters
    ----------
    latlong_series : pandas.Series
        A Pandas Series of strings representing latitude-longitude coordinates 
        in the format "latitude,longitude". Example: ["37.7749,-122.4194", 
        "40.7128,-74.0060", ...].

    Returns
    -------
    list of str
        A list of ISO 3166-1 alpha-2 country codes corresponding to the 
        coordinates in `latlong_series`, or the string 'needs to be checked' 
        if a location cannot be found for a given coordinate.

    """
    # Create a geolocator object for the Nominatim geocoding service
    geolocator = Nominatim(user_agent="my_application")

    # Apply the reverse_geocode() method to all values in latlong_series
    locations = latlong_series.apply(lambda x: geolocator.reverse(x, language="en"))

    # Extract the country code from each location object, or append "needs to be checked"
    # if the location is None
    country_codes = locations.apply(lambda x: x.raw['address']['country_code'] if x is not None else 'needs to be checked')
    
    print(locations)
    # Convert the resulting Pandas Series back to a list and return it
    return country_codes.tolist()

# %%
# assuming your original dataframe is called "df"
df_source_not_inaturalist['country code'] = get_country_code(df_source_not_inaturalist['combined_lat_and_lon'])
# Out:
# 3130    (Salon and Spa Venessa, 8516, Main Street, Dob...
# 3131    (12638, 14th Avenue South, Boulevard Park, Bur...
# 3132    (Walygator Sud-Ouest, Route d'Agen, Roquefort,...
# 3133    (16231, Windemeir Lane, Huntington Beach, Oran...
# 3134    (Huatugou, Mangnai City, Haixi Mongol and Tibe...
#                               ...
# 3456    (Alte Ziegelei, August-Bebel-Straße, Neukirche...
# 3457    (5, Fabricestraße, Albertstadt, Neustadt, Dres...
# 3458    (58, Friedrich-Rottra-Straße, Efringen-Kirchen...
# 3459    (Station Jannowitzbrücke, Brücke 2, Rolandufer...
# 3460    (9а, Starostynska Street, Ostroh, Ostroh Urban...
# Name: combined_lat_and_lon, Length: 331, dtype: object
# C:\Users\Jeffrey\AppData\Local\Temp\ipykernel_7500\1469592704.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_source_not_inaturalist['country code'] = get_country_code(df_source_not_inaturalist['combined_lat_and_lon'])

# %%
df_source_not_inaturalist.to_csv('small dataset with country codes.csv')

# %%
def get_continent_name(continent_code: str) -> str:
    """
    Given a continent's code, returns the continent name as a whole string
    
    Args:
        continent_code(str): continent code
    """
    # dictionary of continent codes
    continent_dict = {
        "NA": "North America",
        "SA": "South America",
        "AS": "Asia",
        "AF": "Africa",
        "OC": "Oceania",
        "EU": "Europe",
        "AQ" : "Antarctica"
    }
    return continent_dict[continent_code]

# initialize continent list
continent_full = []


def get_continent_name(country_code):
    """
    Given an ISO 3166-1 alpha-2 country code or the string 'needs to be checked', 
    returns the corresponding continent name using the pycountry_convert library. 
    If the code is 'needs to be checked', the string 'needs to be checked' is returned 
    instead of a continent name.

    Parameters
    ----------
    country_code : str
        An ISO 3166-1 alpha-2 country code or the string 'needs to be checked'. 
        Example: 'US', 'CA', 'MX', 'needs to be checked'.

    Returns
    -------
    str
        The continent name corresponding to the code, or the string 'needs to be checked' 
        if the code is 'needs to be checked'.

    """
    # Convert the code to uppercase
    country_code = country_code.upper()

    # Check if the code is 'needs to be checked'
    if country_code == 'NEEDS TO BE CHECKED':
        return 'needs to be checked'

    # Use pycountry_convert to convert the code to a continent name
    try:
        country_continent_code = pc.country_alpha2_to_continent_code(country_code)
        continent_name = pc.convert_continent_code_to_continent_name(country_continent_code)
        return continent_name
    except KeyError:
        # If the code is not recognized, return 'needs to be checked'
        return 'needs to be checked'

# %%
# assuming your original dataframe is called "df"
df_source_not_inaturalist['continent name'] = df_source_not_inaturalist['country code'].apply(get_continent_name)
# Out:
# C:\Users\Jeffrey\AppData\Local\Temp\ipykernel_7500\298890918.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_source_not_inaturalist['continent name'] = df_source_not_inaturalist['country code'].apply(get_continent_name)

# %%
df_source_not_inaturalist
# Out:
#       id           observed_on_string    observed_on      time_observed_at  \
# 3130 NaN      Wednesday, June 9, 2010  6/9/2010 0:00                   NaN
# 3131 NaN  Wednesday, October 11, 2006       ########                   NaN
# 3132 NaN     Sunday, February 8, 2015  2/8/2015 0:00                   NaN
# 3133 NaN      Thursday, July 24, 2014       ########                   NaN
# 3134 NaN     Saturday, March 31, 2012       ########                   NaN
# ...   ..                          ...            ...                   ...
# 3456 NaN                          NaN     18/10/2021      18/10/2021 00:00
# 3457 NaN                          NaN     18/10/2021      18/10/2021 00:00
# 3458 NaN                          NaN     18/10/2021      18/10/2021 00:00
# 3459 NaN                          NaN     31/10/2021      31/10/2021 00:00
# 3460 NaN                          NaN  8/5/2022 0:00   08.05.2022 09:52:04
#
#                        time_zone  user_id                 user_login  \
# 3130  Eastern Time (US & Canada)      NaN               John Chulick
# 3131       Pacific Daylight Time      NaN           Cheryl Moorehead
# 3132       Central European Time      NaN                   Debouvry
# 3133       Pacific Daylight Time      NaN               Mollivan Jon
# 3134       Central Daylight Time      NaN                Coastlander
# ...                          ...      ...                        ...
# 3456                     Germany      NaN                naturgucker
# 3457                     Germany      NaN                naturgucker
# 3458                     Germany      NaN                naturgucker
# 3459                     Germany      NaN                naturgucker
# 3460                     Ukraine      NaN  Ð¡Ñ‚Ð°Ð½Ð¸ÑÐ»Ð°Ð²Ð° Ð Ð¾
#
#      user_name created_at updated_at  ... place_state_name place_country_name  \
# 3130       NaN        NaN        NaN  ...              NaN                NaN
# 3131       NaN        NaN        NaN  ...              NaN                NaN
# 3132       NaN        NaN        NaN  ...              NaN                NaN
# 3133       NaN        NaN        NaN  ...              NaN                NaN
# 3134       NaN        NaN        NaN  ...              NaN                NaN
# ...        ...        ...        ...  ...              ...                ...
# 3456       NaN        NaN        NaN  ...              NaN                NaN
# 3457       NaN        NaN        NaN  ...              NaN                NaN
# 3458       NaN        NaN        NaN  ...              NaN                NaN
# 3459       NaN        NaN        NaN  ...              NaN                NaN
# 3460       NaN        NaN        NaN  ...              NaN                NaN
#
#                species_guess         scientific_name  common_name  \
# 3130  Hesperomyces harmoniae  Hesperomyces harmoniae          NaN
# 3131  Hesperomyces harmoniae  Hesperomyces harmoniae          NaN
# 3132  Hesperomyces harmoniae  Hesperomyces harmoniae          NaN
# 3133  Hesperomyces harmoniae  Hesperomyces harmoniae          NaN
# 3134  Hesperomyces harmoniae  Hesperomyces harmoniae          NaN
# ...                      ...                     ...          ...
# 3456  Hesperomyces harmoniae  Hesperomyces harmoniae          NaN
# 3457  Hesperomyces harmoniae  Hesperomyces harmoniae          NaN
# 3458  Hesperomyces harmoniae  Hesperomyces harmoniae          NaN
# 3459  Hesperomyces harmoniae  Hesperomyces harmoniae          NaN
# 3460  Hesperomyces harmoniae  Hesperomyces harmoniae          NaN
#
#      iconic_taxon_name taxon_id       Source  country code continent name
# 3130             Fungi      NaN       Flickr            us  North America
# 3131             Fungi      NaN       Flickr            us  North America
# 3132             Fungi      NaN       Flickr            fr         Europe
# 3133             Fungi      NaN       Flickr            us  North America
# 3134             Fungi      NaN       Flickr            cn           Asia
# ...                ...      ...          ...           ...            ...
# 3456             Fungi      NaN  Naturgucker            de         Europe
# 3457             Fungi      NaN  Naturgucker            de         Europe
# 3458             Fungi      NaN  Naturgucker            de         Europe
# 3459             Fungi      NaN  Naturgucker            de         Europe
# 3460             Fungi      NaN  Naturgucker            ua         Europe
#
# [331 rows x 47 columns]

# %%
# create a csv with the applied country and continents
df_source_not_inaturalist.to_csv('small dataset with country codes and country names.csv')

# %%
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut

def get_country_name(country_code, timeout=5):
    """
    Returns the country name based on the given country code.

    Args:
        country_code (str): Country code (ISO 3166-1 alpha-2).
        timeout (int): Timeout value for the geocoding request in seconds. Default is 5 seconds.

    Returns:
        str: Country name.

    Example:
        >>> get_country_name("PL")
        'Poland'
    """
    geolocator = Nominatim(user_agent="country_info")
    location = None
    try:
        location = geolocator.geocode(country_code, exactly_one=True, timeout=timeout)
    except GeocoderTimedOut:
        return get_country_name(country_code, timeout=timeout)  # Retry the request in case of timeout error
    
    if location:
        return location.address.split(",")[-1].strip()
    else:
        return None

# %%
# assuming your original dataframe is called "df"
df_source_not_inaturalist['country name'] = df_source_not_inaturalist['country code'].apply(get_country_name)
# Out:
# C:\Users\Jeffrey\AppData\Local\Temp\ipykernel_7500\1968488472.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_source_not_inaturalist['country name'] = df_source_not_inaturalist['country code'].apply(get_country_name)

# %%
# create a csv with the applied country and continents
df_source_not_inaturalist.to_csv('small dataset with country codes and country names.csv')
