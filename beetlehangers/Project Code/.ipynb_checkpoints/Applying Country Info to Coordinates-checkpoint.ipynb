# %%
pip install pycountry
# Out:
# Collecting pycountry
#   Downloading pycountry-22.3.5.tar.gz (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 25.5 MB/s eta 0:00:0000:010:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: setuptools in /Users/jeffreypan/opt/anaconda3/lib/python3.8/site-packages (from pycountry) (67.4.0)
# Building wheels for collected packages: pycountry
#   Building wheel for pycountry (pyproject.toml) ... done
#   Created wheel for pycountry: filename=pycountry-22.3.5-py2.py3-none-any.whl size=10681832 sha256=68efa282f9f9aba0d4cdf4de2ebcfab0625e0e16bb02bd43c2778efc29567518
#   Stored in directory: /Users/jeffreypan/Library/Caches/pip/wheels/e2/aa/0f/c224e473b464387170b83ca7c66947b4a7e33e8d903a679748
# Successfully built pycountry
# Installing collected packages: pycountry
# Successfully installed pycountry-22.3.5
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pycountry_convert
# Out:
# Collecting pycountry_convert
#   Downloading pycountry_convert-0.7.2-py3-none-any.whl (13 kB)
# Requirement already satisfied: pycountry>=16.11.27.1 in /Users/jeffreypan/opt/anaconda3/lib/python3.8/site-packages (from pycountry_convert) (22.3.5)
# Collecting repoze.lru>=0.7
#   Downloading repoze.lru-0.7-py3-none-any.whl (10 kB)
# Collecting pytest-cov>=2.5.1
#   Using cached pytest_cov-4.0.0-py3-none-any.whl (21 kB)
# Requirement already satisfied: wheel>=0.30.0 in /Users/jeffreypan/opt/anaconda3/lib/python3.8/site-packages (from pycountry_convert) (0.38.4)
# Collecting pytest-mock>=1.6.3
#   Downloading pytest_mock-3.10.0-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: pytest>=3.4.0 in /Users/jeffreypan/opt/anaconda3/lib/python3.8/site-packages (from pycountry_convert) (6.2.3)
# Collecting pprintpp>=0.3.0
#   Downloading pprintpp-0.4.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: setuptools in /Users/jeffreypan/opt/anaconda3/lib/python3.8/site-packages (from pycountry>=16.11.27.1->pycountry_convert) (67.4.0)
# Requirement already satisfied: attrs>=19.2.0 in /Users/jeffreypan/opt/anaconda3/lib/python3.8/site-packages (from pytest>=3.4.0->pycountry_convert) (20.3.0)
# Requirement already satisfied: iniconfig in /Users/jeffreypan/opt/anaconda3/lib/python3.8/site-packages (from pytest>=3.4.0->pycountry_convert) (1.1.1)
# Requirement already satisfied: packaging in /Users/jeffreypan/opt/anaconda3/lib/python3.8/site-packages (from pytest>=3.4.0->pycountry_convert) (20.9)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in /Users/jeffreypan/opt/anaconda3/lib/python3.8/site-packages (from pytest>=3.4.0->pycountry_convert) (0.13.1)
# Requirement already satisfied: py>=1.8.2 in /Users/jeffreypan/opt/anaconda3/lib/python3.8/site-packages (from pytest>=3.4.0->pycountry_convert) (1.10.0)
# Requirement already satisfied: toml in /Users/jeffreypan/opt/anaconda3/lib/python3.8/site-packages (from pytest>=3.4.0->pycountry_convert) (0.10.2)
# Collecting coverage[toml]>=5.2.1
#   Downloading coverage-7.2.1-cp38-cp38-macosx_10_9_x86_64.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.3/199.3 kB 2.8 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: tomli in /Users/jeffreypan/opt/anaconda3/lib/python3.8/site-packages (from coverage[toml]>=5.2.1->pytest-cov>=2.5.1->pycountry_convert) (2.0.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/jeffreypan/opt/anaconda3/lib/python3.8/site-packages (from packaging->pytest>=3.4.0->pycountry_convert) (2.4.7)
# Installing collected packages: repoze.lru, pprintpp, coverage, pytest-mock, pytest-cov, pycountry_convert
# Successfully installed coverage-7.2.1 pprintpp-0.4.0 pycountry_convert-0.7.2 pytest-cov-4.0.0 pytest-mock-3.10.0 repoze.lru-0.7
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Applying Country Codes to Main Dataset
#
# Using the pycountry package, the country codes will be applied to the Main Dataset for graphing purposes, such as heatmaps.

# %%
import pycountry
import pandas as pd
import numpy as np
import pycountry_convert as pc

# %%
# ADDING COUNTRIES FOR ANALYSIS
df = pd.read_csv('Data/Main Dataset with no States.csv')

# %%
# looking at data
df.head(10)
# Out:
#    id        observed_on_string  observed_on  Unnamed: 3  year  \
# 0 NaN   Jun 10, 20179:27 PM EDT  6/7/17 0:00         NaN  2017
# 1 NaN    Jun 6, 20175:31 PM PDT  6/3/17 0:00         NaN  2017
# 2 NaN    Jun 4, 20172:28 PM EDT     ########         NaN  2017
# 3 NaN   May 17, 20179:32 AM PDT     ########         NaN  2017
# 4 NaN    May 5, 20179:13 PM PDT  5/4/17 0:00         NaN  2017
# 5 NaN    May 5, 20177:04 PM MDT     ########         NaN  2017
# 6 NaN   Apr 20, 20176:02 AM EDT     ########         NaN  2017
# 7 NaN   Mar 17, 20176:15 PM CDT     ########         NaN  2017
# 8 NaN   Mar 3, 201710:42 PM PST  3/3/17 0:00         NaN  2017
# 9 NaN  Feb 25, 201711:16 PM EST     ########         NaN  2017
#
#   time_observed_at                   time_zone  user_id      user_login  \
# 0     12:52 PM EDT  Eastern Time (US & Canada)      NaN           srall
# 1     07:58 PM PDT       Pacific Daylight Time      NaN  psyllidhipster
# 2     12:11 PM EDT  Eastern Time (US & Canada)      NaN           srall
# 3     12:52 PM PDT       Pacific Daylight Time      NaN        leptonia
# 4     12:21 PM PDT       Pacific Daylight Time      NaN        leptonia
# 5              NaN       Central Daylight Time      NaN        bug_eric
# 6      4:07 PM EDT  Eastern Time (US & Canada)      NaN         rcurtis
# 7              NaN       Central Daylight Time      NaN      sambiology
# 8     12:09 PM PST       Pacific Daylight Time      NaN        leptonia
# 9     12:40 PM EST  Eastern Time (US & Canada)      NaN             djm
#
#         Source  ...                                       url  \
# 0  iNaturalist  ...  www.inaturalist.org/observations/6584427
# 1  iNaturalist  ...  www.inaturalist.org/observations/6528794
# 2  iNaturalist  ...  www.inaturalist.org/observations/6496118
# 3  iNaturalist  ...  www.inaturalist.org/observations/6248462
# 4  iNaturalist  ...  www.inaturalist.org/observations/6107443
# 5  iNaturalist  ...  www.inaturalist.org/observations/6105775
# 6  iNaturalist  ...  www.inaturalist.org/observations/5869526
# 7  iNaturalist  ...  www.inaturalist.org/observations/5383613
# 8  iNaturalist  ...  www.inaturalist.org/observations/5221081
# 9  iNaturalist  ...  www.inaturalist.org/observations/5180720
#
#                                            image_url  \
# 0  https://static.inaturalist.org/photos/8346387/...
# 1  https://static.inaturalist.org/photos/8271424/...
# 2  https://static.inaturalist.org/photos/8219131/...
# 3  https://static.inaturalist.org/photos/7855551/...
# 4  https://static.inaturalist.org/photos/7641906/...
# 5  https://static.inaturalist.org/photos/7639496/...
# 6  https://static.inaturalist.org/photos/7301169/...
# 7  https://static.inaturalist.org/photos/6610935/...
# 8  https://static.inaturalist.org/photos/6453213/...
# 9  https://static.inaturalist.org/photos/6390116/...
#
#                                          place_guess  latitude  longitude  \
# 0                       Bedminster Township, NJ, USA  40.66750   74.64596
# 1                               Kern County, CA, USA  35.03660   18.76968
# 2                         Bound Brook, NJ 08805, USA  40.56037   74.52893
# 3  University of California, Santa Cruz, Santa Cr...  36.99912 -122.05200
# 4  University of California, Santa Cruz, Santa Cr...  36.99596   22.05147
# 5                              Broken Arrow Oklahoma  35.95958  -95.74980
# 6                                    Indigo lake, oh  41.19106  -81.58590
# 7                       Cedar Hill State Park, Texas  32.61252  -96.99550
# 8  University of California, Santa Cruz, Santa Cr...  36.99886   22.05169
# 9                 Cornell University, Ithaca, NY, US  42.44875   76.47549
#
#          species_guess         scientific_name          common_name  taxon_id  \
# 0  Green Beetle Hanger  Hesperomyces virescens  Green Beetle Hanger       NaN
# 1  Green Beetle Hanger  Hesperomyces virescens  Green Beetle Hanger       NaN
# 2  Green Beetle Hanger  Hesperomyces virescens  Green Beetle Hanger       NaN
# 3  Green Beetle Hanger  Hesperomyces virescens  Green Beetle Hanger       NaN
# 4  Green Beetle Hanger  Hesperomyces virescens  Green Beetle Hanger       NaN
# 5  Green Beetle Hanger  Hesperomyces virescens  Green Beetle Hanger       NaN
# 6  Green Beetle Hanger  Hesperomyces virescens  Green Beetle Hanger       NaN
# 7  Green Beetle Hanger  Hesperomyces virescens  Green Beetle Hanger       NaN
# 8  Green Beetle Hanger  Hesperomyces virescens  Green Beetle Hanger       NaN
# 9  Green Beetle Hanger  Hesperomyces virescens  Green Beetle Hanger       NaN
#
#   combined lat and long
# 0      40.6675,74.64596
# 1      35.0366,18.76968
# 2     40.56037,74.52893
# 3     36.99912,-122.052
# 4     36.99596,22.05147
# 5     35.95958,-95.7498
# 6     41.19106,-81.5859
# 7     32.61252,-96.9955
# 8     36.99886,22.05169
# 9     42.44875,76.47549
#
# [10 rows x 24 columns]

# %%
# testing out pycountry package
france = pycountry.countries.get(alpha_2='FR')
france
# Out:
# Country(alpha_2='FR', alpha_3='FRA', flag='🇫🇷', name='France', numeric='250', official_name='French Republic')

# %%
from geopy.geocoders import Nominatim
import pandas as pd

def get_country_code(latlong_series):
    """
    Given a Pandas Series of latitude-longitude coordinates, returns a list of 
    corresponding country codes obtained through reverse geocoding using the 
    Nominatim geocoding service from the geopy library. If a location cannot be 
    found for a given coordinate, the string 'needs to be checked' is returned 
    instead of a country code.

    Parameters
    ----------
    latlong_series : pandas.Series
        A Pandas Series of strings representing latitude-longitude coordinates 
        in the format "latitude,longitude". Example: ["37.7749,-122.4194", 
        "40.7128,-74.0060", ...].

    Returns
    -------
    list of str
        A list of ISO 3166-1 alpha-2 country codes corresponding to the 
        coordinates in `latlong_series`, or the string 'needs to be checked' 
        if a location cannot be found for a given coordinate.

    """
    # Create a geolocator object for the Nominatim geocoding service
    geolocator = Nominatim(user_agent="my_application")

    # Apply the reverse_geocode() method to all values in latlong_series
    locations = latlong_series.apply(lambda x: geolocator.reverse(x, language="en"))

    # Extract the country code from each location object, or append "needs to be checked"
    # if the location is None
    country_codes = locations.apply(lambda x: x.raw['address']['country_code'] if x is not None else 'needs to be checked')

    # Convert the resulting Pandas Series back to a list and return it
    return country_codes.tolist()

# %%
# assuming your original dataframe is called "df"
df['country code'] = get_country_code(df['combined lat and long'])

# %%
def get_continent_name(continent_code: str) -> str:
    """
    Given a continent's code, returns the continent name as a whole string
    
    Args:
        continent_code(str): continent code
    """
    # dictionary of continent codes
    continent_dict = {
        "NA": "North America",
        "SA": "South America",
        "AS": "Asia",
        "AF": "Africa",
        "OC": "Oceania",
        "EU": "Europe",
        "AQ" : "Antarctica"
    }
    return continent_dict[continent_code]

# initialize continent list
continent_full = []


def get_continent_name(country_code):
    """
    Given an ISO 3166-1 alpha-2 country code or the string 'needs to be checked', 
    returns the corresponding continent name using the pycountry_convert library. 
    If the code is 'needs to be checked', the string 'needs to be checked' is returned 
    instead of a continent name.

    Parameters
    ----------
    country_code : str
        An ISO 3166-1 alpha-2 country code or the string 'needs to be checked'. 
        Example: 'US', 'CA', 'MX', 'needs to be checked'.

    Returns
    -------
    str
        The continent name corresponding to the code, or the string 'needs to be checked' 
        if the code is 'needs to be checked'.

    """
    # Convert the code to uppercase
    country_code = country_code.upper()

    # Check if the code is 'needs to be checked'
    if country_code == 'NEEDS TO BE CHECKED':
        return 'needs to be checked'

    # Use pycountry_convert to convert the code to a continent name
    try:
        country_continent_code = pc.country_alpha2_to_continent_code(country_code)
        continent_name = pc.convert_continent_code_to_continent_name(country_continent_code)
        return continent_name
    except KeyError:
        # If the code is not recognized, return 'needs to be checked'
        return 'needs to be checked'

# %%
# assuming your original dataframe is called "df"
df['continent name'] = df['country code'].apply(get_continent_name)

# %%
df
# Out:
#               id       observed_on_string  observed_on  Unnamed: 3  year  \
# 0            NaN  Jun 10, 20179:27 PM EDT  6/7/17 0:00         NaN  2017
# 1            NaN   Jun 6, 20175:31 PM PDT  6/3/17 0:00         NaN  2017
# 2            NaN   Jun 4, 20172:28 PM EDT     ########         NaN  2017
# 3            NaN  May 17, 20179:32 AM PDT     ########         NaN  2017
# 4            NaN   May 5, 20179:13 PM PDT  5/4/17 0:00         NaN  2017
# ..           ...                      ...          ...         ...   ...
# 669  113000000.0                 ########   28/04/2022         NaN   NaN
# 670  114000000.0                 ########   29/04/2022         NaN   NaN
# 671  115000000.0                 ########  2/5/22 0:00         NaN   NaN
# 672  115000000.0     2022-05-02 15:56:46Z  2/5/22 0:00         NaN   NaN
# 673          NaN                      NaN  8/5/22 0:00         NaN   NaN
#
#             time_observed_at                   time_zone    user_id  \
# 0               12:52 PM EDT  Eastern Time (US & Canada)        NaN
# 1               07:58 PM PDT       Pacific Daylight Time        NaN
# 2               12:11 PM EDT  Eastern Time (US & Canada)        NaN
# 3               12:52 PM PDT       Pacific Daylight Time        NaN
# 4               12:21 PM PDT       Pacific Daylight Time        NaN
# ..                       ...                         ...        ...
# 669  2022-04-28 11:04:00 UTC                      Berlin  1417816.0
# 670  2022-04-29 08:33:00 UTC                      Vienna  2467347.0
# 671  2022-05-02 16:21:38 UTC                      Vienna  4323624.0
# 672  2022-05-02 15:56:46 UTC                      London   353381.0
# 673      08.05.2022 09:52:04                     Ukraine        NaN
#
#                     user_login                                      Source  \
# 0                        srall                                 iNaturalist
# 1               psyllidhipster                                 iNaturalist
# 2                        srall                                 iNaturalist
# 3                     leptonia                                 iNaturalist
# 4                     leptonia                                 iNaturalist
# ..                         ...                                         ...
# 669            bernhard_hiller                                 iNaturalist
# 670                gertiseiser                                 iNaturalist
# 671                hederahelix                                 iNaturalist
# 672        wildhamandpetersham                                 iNaturalist
# 673  Ð¡Ñ‚Ð°Ð½Ð¸ÑÐ»Ð°Ð²Ð° Ð Ð¾  Ukrainian Biodiversity Information Network
#
#      ...                                        place_guess   latitude  \
# 0    ...                       Bedminster Township, NJ, USA  40.667500
# 1    ...                               Kern County, CA, USA  35.036600
# 2    ...                         Bound Brook, NJ 08805, USA  40.560370
# 3    ...  University of California, Santa Cruz, Santa Cr...  36.999120
# 4    ...  University of California, Santa Cruz, Santa Cr...  36.995960
# ..   ...                                                ...        ...
# 669  ...            Bad Kreuznach, Rheinland-Pfalz, Germany  49.830470
# 670  ...            Leopoldstadt, 1020 Wien, Ãƒâ€“sterreich  48.200670
# 671  ...                                 Wien, AT-WI-WS, AT  48.193220
# 672  ...        Richmond upon Thames, Richmond, England, GB  51.440960
# 673  ...                                                NaN  50.327756
#
#       longitude        species_guess         scientific_name  \
# 0     74.645960  Green Beetle Hanger  Hesperomyces virescens
# 1     18.769680  Green Beetle Hanger  Hesperomyces virescens
# 2     74.528930  Green Beetle Hanger  Hesperomyces virescens
# 3   -122.052000  Green Beetle Hanger  Hesperomyces virescens
# 4     22.051470  Green Beetle Hanger  Hesperomyces virescens
# ..          ...                  ...                     ...
# 669    7.712056  Green Beetle Hanger  Hesperomyces virescens
# 670   16.414260  Green Beetle Hanger  Hesperomyces virescens
# 671   16.374320   MarienkÃƒÂ¤ferpilz  Hesperomyces virescens
# 672   -0.323020  Green Beetle Hanger  Hesperomyces virescens
# 673   26.514446  Green Beetle Hanger  Hesperomyces virescens
#
#              common_name taxon_id  combined lat and long         country code  \
# 0    Green Beetle Hanger      NaN       40.6675,74.64596                   kg
# 1    Green Beetle Hanger      NaN       35.0366,18.76968  needs to be checked
# 2    Green Beetle Hanger      NaN      40.56037,74.52893                   kg
# 3    Green Beetle Hanger      NaN      36.99912,-122.052                   us
# 4    Green Beetle Hanger      NaN      36.99596,22.05147                   gr
# ..                   ...      ...                    ...                  ...
# 669  Green Beetle Hanger      NaN      49.83047,7.712056                   de
# 670  Green Beetle Hanger      NaN      48.20067,16.41426                   at
# 671  Green Beetle Hanger      NaN      48.19322,16.37432                   at
# 672  Green Beetle Hanger      NaN      51.44096,-0.32302                   gb
# 673  Green Beetle Hanger      NaN    50.327756,26.514446                   ua
#
#           continent name
# 0                   Asia
# 1    needs to be checked
# 2                   Asia
# 3          North America
# 4                 Europe
# ..                   ...
# 669               Europe
# 670               Europe
# 671               Europe
# 672               Europe
# 673               Europe
#
# [674 rows x 26 columns]

# %%
# create a csv with the applied country and continents

df.to_csv('Main Dataset.csv')
